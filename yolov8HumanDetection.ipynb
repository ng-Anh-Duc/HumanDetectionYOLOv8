# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 19592, done.
# remote: Counting objects: 100% (746/746), done.
# remote: Compressing objects: 100% (582/582), done.
# remote: Total 19592 (delta 410), reused 332 (delta 163), pack-reused 18846
# Receiving objects: 100% (19592/19592), 11.44 MiB | 18.86 MiB/s, done.
# Resolving deltas: 100% (13525/13525), done.

# %%
# %cd ultralytics
# !pip install ultralytics
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.236 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !mv "/content/drive/MyDrive/yolov8s.pt" "/content/ultralytics/"

# %%
# !mv "/content/drive/MyDrive/human_detection_dataset.zip" "/content/"
# !gdown https://drive.google.com/u/0/uc?id=1--0QuKMwj31K -CSvD8oq5fceFweiFPuN& export=download
# !unzip /content/human_detection_dataset.zip

# %%
# !unzip "/content/human_detection_dataset.zip"
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: human_detection_dataset/val/images/frame56007.45.00-07.50.00.jpg
#   inflating: __MACOSX/human_detection_dataset/val/images/._frame56007.45.00-07.50.00.jpg
#   inflating: human_detection_dataset/val/images/frame204007.45.00-07.50.00.jpg
#   inflating: __MACOSX/human_detection_dataset/val/images/._frame204007.45.00-07.50.00.jpg
#   inflating: human_detection_dataset/val/images/frame464008.00.00-08.05.00.jpg
#   inflating: __MACOSX/human_detection_dataset/val/images/._frame464008.00.00-08.05.00.jpg
#   inflating: human_detection_dataset/val/images/frame312008.05.00-08.10.00.jpg
#   inflating: __MACOSX/human_detection_dataset/val/images/._frame312008.05.00-08.10.00.jpg
#   inflating: human_detection_dataset/val/images/frame572007.40.00-07.45.00.jpg
#   inflating: __MACOSX/human_detection_dataset/val/images/._frame572007.40.00-07.45.00.jpg
# ...

# %%
# !yolo train model=yolov8s.pt data=/content/ultralytics/human_detection_dataset/data.yaml epochs=20 imgsz =640
# Out:
# Ultralytics YOLOv8.0.236 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !mv '/content/drive/MyDrive/putin.jpeg' '/content/'

# %%
# !yolo predict model = /content/ultralytics/runs/detect/train2/weights/best.pt source='/content/putin.jpeg'
# Out:
# Ultralytics YOLOv8.0.236 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/putin.jpeg: 448x640 3 Humans, 188.1ms
# Speed: 8.4ms preprocess, 188.1ms inference, 988.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/ultralytics/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model = /content/ultralytics/runs/detect/train2/weights/best.pt source='/content/Katy Perry - Roar.mp4'
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# video 1/1 (1456/6452) /content/Katy Perry - Roar.mp4: 384x640 (no detections), 11.3ms
# video 1/1 (1457/6452) /content/Katy Perry - Roar.mp4: 384x640 (no detections), 11.0ms
# video 1/1 (1458/6452) /content/Katy Perry - Roar.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (1459/6452) /content/Katy Perry - Roar.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (1460/6452) /content/Katy Perry - Roar.mp4: 384x640 (no detections), 10.8ms
# video 1/1 (1461/6452) /content/Katy Perry - Roar.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (1462/6452) /content/Katy Perry - Roar.mp4: 384x640 (no detections), 10.8ms
# video 1/1 (1463/6452) /content/Katy Perry - Roar.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (1464/6452) /content/Katy Perry - Roar.mp4: 384x640 (no detections), 11.7ms
# video 1/1 (1465/6452) /content/Katy Perry - Roar.mp4: 384x640 (no detections), 10.8ms
# ...
